# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data=pd.read_csv('data.csv')
data
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df=data.drop(['date','street','statezip','country','sqft_lot'],axis=1)

# %%
y=data['price']
y
# Out:
# 0       3.130000e+05
# 1       2.384000e+06
# 2       3.420000e+05
# 3       4.200000e+05
# 4       5.500000e+05
#             ...
# 4595    3.081667e+05
# 4596    5.343333e+05
# 4597    4.169042e+05
# 4598    2.034000e+05
# 4599    2.206000e+05
# Name: price, Length: 4600, dtype: float64

# %%
# Out:
# LinearRegression()

# %%
model.predict(x_test)
# Out:
# array([ 429677.32365137,  472061.62855225,  795365.64059093,
#         774173.48814049,  633713.63457159,  450869.47610181,
#         633713.63457159,  687597.63657804,  450869.47610181,
#         708789.78902848,  633713.63457159,  633713.63457159,
#         504753.47810825,  450869.47610181,  612521.48212115,
#         633713.63457159,  762673.79103493,  579829.63256514,
#         429677.32365137,  504753.47810825,  612521.48212115,
#         633713.63457159,  396985.47409536,  450869.47610181,
#         633713.63457159,  504753.47810825,  741481.63858449,
#         268025.31763202,  396985.47409536,  774173.48814049,
#         816557.79304138,  612521.48212115,  612521.48212115,
#         720289.48613405,  762673.79103493,  450869.47610181,
#         558637.4801147 ,  558637.4801147 ,  268025.31763202,
#         289217.47008246,  537445.32766426,  396985.47409536,
#         268025.31763202,  579829.63256514,  289217.47008246,
# ...

# %%
model.score(x_test,y_test)
# Out:
# 0.1292467385933821

# %%
x=data.drop(['price'],axis=1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
model=LinearRegression()
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.48675691104523156

# %%
data
# Out:
#                      date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     2014-05-02 00:00:00       3.0       1.50         1340      7912     1.5
# 1     2014-05-02 00:00:00       5.0       2.50         3650      9050     2.0
# 2     2014-05-02 00:00:00       3.0       2.00         1930     11947     1.0
# 3     2014-05-02 00:00:00       3.0       2.25         2000      8030     1.0
# 4     2014-05-02 00:00:00       4.0       2.50         1940     10500     1.0
# ...                   ...       ...        ...          ...       ...     ...
# 4595  2014-07-09 00:00:00       3.0       1.75         1510      6360     1.0
# 4596  2014-07-09 00:00:00       3.0       2.50         1460      7573     2.0
# 4597  2014-07-09 00:00:00       3.0       2.50         3010      7014     2.0
# 4598  2014-07-10 00:00:00       4.0       2.00         2090      6630     1.0
# 4599  2014-07-10 00:00:00       3.0       2.50         1490      8102     2.0
#
# ...

# %%
data.drop(['yr_built','yr_renovated','price'],axis=1,inplace=True)

# %%
data
# Out:
#                      date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     2014-05-02 00:00:00       3.0       1.50         1340      7912     1.5
# 1     2014-05-02 00:00:00       5.0       2.50         3650      9050     2.0
# 2     2014-05-02 00:00:00       3.0       2.00         1930     11947     1.0
# 3     2014-05-02 00:00:00       3.0       2.25         2000      8030     1.0
# 4     2014-05-02 00:00:00       4.0       2.50         1940     10500     1.0
# ...                   ...       ...        ...          ...       ...     ...
# 4595  2014-07-09 00:00:00       3.0       1.75         1510      6360     1.0
# 4596  2014-07-09 00:00:00       3.0       2.50         1460      7573     2.0
# 4597  2014-07-09 00:00:00       3.0       2.50         3010      7014     2.0
# 4598  2014-07-10 00:00:00       4.0       2.00         2090      6630     1.0
# 4599  2014-07-10 00:00:00       3.0       2.50         1490      8102     2.0
#
# ...

# %%
data.drop(['date','street','statezip','country','sqft_lot'],axis=1,inplace=True)

# %%
data.drop(['city'],axis=1,inplace=True)

# %%
data.drop(['floors','waterfront','view','condition'],axis=1,inplace=True)

# %%
data
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_above  sqft_basement
# 0          3.0       1.50         1340        1340              0
# 1          5.0       2.50         3650        3370            280
# 2          3.0       2.00         1930        1930              0
# 3          3.0       2.25         2000        1000           1000
# 4          4.0       2.50         1940        1140            800
# ...        ...        ...          ...         ...            ...
# 4595       3.0       1.75         1510        1510              0
# 4596       3.0       2.50         1460        1460              0
# 4597       3.0       2.50         3010        3010              0
# 4598       4.0       2.00         2090        1070           1020
# 4599       3.0       2.50         1490        1490              0
#
# [4600 rows x 5 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(data,y,test_size=0.2)

# %%
lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.score(x_test,y_test)
# Out:
# 0.47162869393209084
